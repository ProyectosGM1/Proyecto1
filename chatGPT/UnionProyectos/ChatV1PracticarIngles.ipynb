# %% [markdown]
# ## CONNECCION ENTRE CHTGPT Y DEEPLEARN PARA HABLAR Y PRACTICAR INGLES
# #### * Importar funciones de python
# #### * Importar funciones de deeplearn
# #### * Simplificar para que solo se manden mensajes, audios y se practique

# %%
# Importar funciones de python
import nbimporter
import  chatGPT.UnionProyectos.funcionesChat as funcionesChat
import time

# %%
#probar funciones de python
driver = funcionesChat.conexionChatGpt()
time.sleep(2)
funcionesChat.mandarMensaje(driver, "Hola la cd se inundara en los proximos 10 años")
funcionesChat.click(driver)

# %%
p1 = funcionesChat.leerFiltrar(driver)
p1

# %%
#Importa funciones de deep

# %%
#probar funcioens de deep

# %%
# Configurar promp inicio chatGPT
import funcionesChat
import time

# %%
# Configurar respuestas que se esperan y separarlas en 2 partes 
    # La contesacion del mensaje 
    # Correcciones del mensaje

driver = funcionesChat.conexionChatGpt()
funcionesChat.mandarMensaje(driver,"mi touchpad de computadora no funciona como deberia, no deja subr ni baja y prece que no funciona correctaete")
time.sleep(2)
funcionesChat.click(driver)

# %%
textoWebCompleto = funcionesChat.leerFiltrar(driver)
textoWebCompleto
WebString =""
for mensaje in textoWebCompleto:
    WebString+= mensaje
textoMensajeTuplas = funcionesChat.separar_en_tuplas(WebString) 
textoWebCompleto[0] 
# regresa tuplas de Persona[0], mensaje[1] tomar solo impares y confirmar que el valor anterior sea la persona indicada

# %%
# Conectar con deepGram
import deepgram

# %%
AudioFile = "C:\\Users\\Luis Leo\\Pictures\\Camera Roll\\audio.m4a" 

text = deepgram.translateudioFile(AudioFile)
# Out:
# cuéntenos cuéntanos algo sobre ti ok pues me considero una persona creativa la verdad

# %%
save = deepgram.saveText(text)  # checar que guarde bien el texto

# %%
# promp chatGPT
InitialPromp =  ""

# %%
# Separara mensajes de chatGPT
    # MENSAJES DE RESPUESTA
    # Observaciones hechas

# %%
# Parte Visual

# %%
#

# %%
#

# %%
#
