# %%
import pywhatkit

# %%
numero = 5551466183
msg ="hola "
pywhatkit.sendwhatmsg_instantly(numero,msg,tab_close=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 numero = 5551466183
#       2 msg ="hola "
# ----> 3 pywhatkit.sendwhatmsg_instantly(numero,msg,tab_close=True)
#
# File c:\Users\Luis Leo\AppData\Local\Programs\Python\Python312\Lib\site-packages\pywhatkit\whats.py:25, in sendwhatmsg_instantly(phone_no, message, wait_time, tab_close, close_time)
#      16 def sendwhatmsg_instantly(
#      17     phone_no: str,
#      18     message: str,
#    (...)     21     close_time: int = 3,
#      22 ) -> None:
#      23     """Send WhatsApp Message Instantly"""
# ---> 25     if not core.check_number(number=phone_no):
#      26         raise exceptions.CountryCodeException("Country Code Missing in Phone Number!")
#      28     web.open(f"https://web.whatsapp.com/send?phone={phone_no}&text={quote(message)}")
#
# ...

# %%
import pyautogui, webbrowser

webbrowser.open("https://web.whatsapp.com/send?phone=5551466183")
pyautogui.typewrite("prueba")
